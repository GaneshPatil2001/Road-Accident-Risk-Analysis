# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('indian_roads_dataset.csv')

# %%
data.head()
# Out:
#    accident_id        city        state   latitude  longitude        date  \
# 0            1        Pune  Maharashtra  18.680827  73.930388  22/10/2023
# 1            2      Mumbai  Maharashtra  18.817732  72.790846  21/05/2023
# 2            3      Mumbai  Maharashtra  19.096889  72.819424  10/07/2024
# 3            4  Chandigarh       Punjab  30.787805  76.847507  30/03/2025
# 4            5     Chennai   Tamil Nadu  12.965155  80.283313  25/01/2024
#
#        time day_of_week is_weekend road_type  ...  visibility temperature  \
# 0  05:00:00      Sunday        Yes   Highway  ...         Low          32
# 1  04:00:00      Sunday        Yes     Urban  ...        High          34
# 2  13:00:00   Wednesday         No     Urban  ...         Low          21
# 3  11:00:00      Sunday        Yes     Urban  ...         Low          30
# 4  16:00:00    Thursday         No   Highway  ...        High          24
#
#   traffic_density        cause  accident_severity vehicles_involved  \
# ...

# %%
print(data.columns)
# Out:
# Index(['accident_id', 'city', 'state', 'latitude', 'longitude', 'date', 'time',
#        'day_of_week', 'is_weekend', 'road_type', 'lanes', 'traffic_signal',
#        'Weather', 'visibility', 'temperature', 'traffic_density', 'cause',
#        'accident_severity', 'vehicles_involved', 'casualties', 'is_peak_hour',
#        'festival', 'risk_score'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   accident_id        20000 non-null  int64
#  1   city               20000 non-null  object
#  2   state              20000 non-null  object
#  3   latitude           20000 non-null  float64
#  4   longitude          20000 non-null  float64
#  5   date               20000 non-null  object
#  6   time               20000 non-null  object
#  7   day_of_week        20000 non-null  object
#  8   is_weekend         20000 non-null  object
#  9   road_type          20000 non-null  object
#  10  lanes              20000 non-null  int64
#  11  traffic_signal     20000 non-null  object
#  12  Weather            20000 non-null  object
#  13  visibility         20000 non-null  object
#  14  temperature        20000 non-null  int64
#  15  traffic_density    20000 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# accident_id          0
# city                 0
# state                0
# latitude             0
# longitude            0
# date                 0
# time                 0
# day_of_week          0
# is_weekend           0
# road_type            0
# lanes                0
# traffic_signal       0
# Weather              0
# visibility           0
# temperature          0
# traffic_density      0
# cause                0
# accident_severity    0
# vehicles_involved    0
# casualties           0
# is_peak_hour         0
# festival             0
# risk_score           0
# dtype: int64

# %%
from sqlalchemy import create_engine
username="postgres"
password="gbp9022982252"
host="localhost"
port="5432"
database="Accident Risk Analysis"

engine=create_engine(f'postgresql://{username}:{password}@{host}:{port}/{database}')
engine.connect()
data.to_sql('accidents', engine, if_exists='replace', index=False)
print("Table 'accidents' created successfully in the database.")
# Out:
# Table 'accidents' created successfully in the database.
